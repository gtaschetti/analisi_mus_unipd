# %% [markdown]
# ## Analisi della densità polifonica
#
# Questo notebook analizza la densità polifonica di una composizione: quante e quali voci sono di volta in volta attive.

# %% [markdown]
# ### Importare il codice
#
# Importa le librerie necessarie e definisce `download_html`, che consente di salvare ogni grafico come file HTML interattivo.

# %%
from itertools import cycle
import pandas as pd
import numpy as np
from pathlib import Path
from IPython.display import display, HTML
import base64
from crim_intervals import importScore
import plotly.graph_objects as go

def download_html(fig, filename='chart.html'):
    b64 = base64.b64encode(fig.to_html(include_plotlyjs='cdn').encode()).decode()
    display(HTML(
        f'<a href="data:text/html;base64,{b64}" download="{filename}" '
        f'style="display:inline-block;margin-top:6px;padding:4px 14px;background:#4472C4;'
        f'color:#fff;border-radius:4px;text-decoration:none;font-size:12px;">&#8595; {filename}</a>'
    ))

print('Ok')
# Out:
# Ok

# %% [markdown]
# #### Caricamento della composizione ####

# %% [markdown]
# Caricamento di un file MusicXML dalla cartella locale `Music_Files/`. Modificare il valore di `filename` per cambiare composizione:
#
# - `'Marenzio_o_voi.xml'` — *O voi che sospirate*, Luca Marenzio
# - `'Monteverdi_o_rossignuol.xml'` — *O rossignuol*, Claudio Monteverdi
#
# Se il caricamento è andato a buon fine, `print(piece.metadata)` restituisce titolo e compositore.

# %%
filename = 'Monteverdi_o_rossignuol.xml'  # ← cambia qui per caricare un altro file
url   = f'Music_Files/{filename}'
piece = importScore(url)
print(piece.metadata)
# Out:
# {'title': "O rossignuol ch'in queste verdi fronde", 'composer': 'Claudio Monteverdi', 'date': None}

# %% [markdown]
# In alternativa, è possibile caricare un file da un URL pubblico. Eseguire questa cella *oppure* la precedente, non entrambe.

# %%
url = 'https://crimproject.org/mei/CRIM_Model_0019.mei'
piece = importScore(url)
print(piece.metadata)

# %% [markdown]
# #### Struttura dei dati

# %% [markdown]
# `piece.notes()` restituisce le note e le pause della composizione in forma di tabella. Ogni colonna corrisponde a una voce; l'indice di riga è l'*offset*, ossia la posizione temporale espressa in semiminime a partire da 0.

# %%
n = piece.notes()
n
# Out:
#       Canto Quinto  Alto Tenore Basso
# 0.0    Rest   Rest  Rest     G4  Rest
# 2.0     NaN    NaN   NaN     G4   NaN
# 3.0     NaN    NaN   NaN     G4   NaN
# 4.0      D5    B-4   NaN     G4   NaN
# 6.0      D5    B-4   NaN   Rest   NaN
# ...     ...    ...   ...    ...   ...
# 480.0   F#4    NaN    D4    NaN    D3
# 481.0    G4     G4   NaN    B-3   NaN
# 482.0    A4    NaN   NaN     A3   NaN
# 483.0   NaN    F#4   NaN    NaN   NaN
# 484.0    B4     G4    D4     G3    G2
#
# [477 rows x 5 columns]

# %% [markdown]
# `piece.durations()` restituisce la durata di ogni nota, nella stessa forma tabellare e con lo stesso indice.

# %%
d = piece.durations()
d
# Out:
#        Canto  Quinto  Alto  Tenore  Basso
# 0.0      4.0     4.0  83.0     2.0   87.0
# 2.0      NaN     NaN   NaN     1.0    NaN
# 3.0      NaN     NaN   NaN     1.0    NaN
# 4.0      2.0     2.0   NaN     2.0    NaN
# 6.0      1.0     1.0   NaN     1.0    NaN
# ...      ...     ...   ...     ...    ...
# 480.0    1.0     NaN   4.0     NaN    4.0
# 481.0    1.0     2.0   NaN     1.0    NaN
# 482.0    2.0     NaN   NaN     2.0    NaN
# 483.0    NaN     1.0   NaN     NaN    NaN
# 484.0    4.0     4.0   4.0     4.0    4.0
#
# [477 rows x 5 columns]

# %% [markdown]
# #### Numero di voci attive

# %% [markdown]
# `piece.soundingCount()` restituisce, per ogni evento, il numero di voci di volta in volta attive (*sounding*).

# %%
sound = piece.soundingCount()
sound
# Out:
# 0.0      1
# 2.0      1
# 3.0      1
# 4.0      3
# 6.0      2
#         ..
# 480.0    5
# 481.0    5
# 482.0    5
# 483.0    5
# 484.0    5
# Name: Sounding, Length: 477, dtype: int64

# %% [markdown]
# La stessa informazione può essere visualizzata rapidamente come grafico a barre tramite `.plot.bar()` di pandas.

# %%
sound_plot = sound.plot.bar(figsize=(20, 4), width=1.0, xticks=[])
print('Doppio click sul grafico per ingrandire/rimpicciolire')
sound_plot
# Out:
# Doppio click sul grafico per ingrandire/rimpicciolire
# <Axes: >

# %% [markdown]
# #### Cadenze

# %% [markdown]
# `piece.cadences()` individua le cadenze sulla base di pattern contrappuntistici predefiniti. Per ogni cadenza vengono indicati la tipologia, la sonorità di approdo e altre informazioni.

# %%
cad = piece.cadences()
cad
# Out:
#                        CadType  LeadingTones  CVFs  Low RelLow Tone RelTone  \
# Last
# 48.0          Evaded Authentic           1.0    Cb   G4    P15   B-      m3
# 84.0             Clausula Vera           1.0   CTx   D4    P12    D      P5
# 116.0                Authentic           1.0   CtB  B-2     m3   B-      m3
# 132.0                Authentic           1.0   CTB   G2     P1    G      P8
# 148.0                Authentic           1.0  TCtB   G3     P8    G      P8
# 180.0      Abandoned Authentic          -1.0    cx   A4    M16  NaN     NaN
# 200.0            Clausula Vera           1.0    TC   G3     P8    G      P8
# 220.0  Abandoned Clausula Vera           1.0    zC   G4    P15    G      P8
# 239.0                Authentic           0.0   TCB   G2     P1    G      P8
# 244.0                Authentic           1.0   TCB   G2     P1    G      P8
# 280.0                Authentic           1.0   CTB   D3     P5    D      P5
# 300.0            Clausula Vera           1.0    CT  B-3    m10   B-      m3
# 340.0            Clausula Vera           1.0    TC   G3     P8    G      P8
# 384.0            Clausula Vera           1.0    TC   G4    P15    G      P8
# 404.0                      NaN           NaN  CTCT  B-2     m3   B-      m3
# 448.0                      NaN           NaN    cz  F#4    M14  NaN     NaN
# 484.0                Authentic           1.0  tCTB   G2     P1    G      P8
#
#       TSig  Measure  Beat  Sounding  Progress  SinceLast  ToNext
# Last
# 48.0   4/4     13.0   1.0         3  0.099174       48.0    36.0
# 84.0   4/4     22.0   1.0         3  0.173554       36.0    32.0
# 116.0  4/4     30.0   1.0         4  0.239669       32.0    16.0
# 132.0  4/4     34.0   1.0         4  0.272727       16.0    16.0
# 148.0  4/4     38.0   1.0         5  0.305785       16.0    32.0
# 180.0  4/4     46.0   1.0         2  0.371901       32.0    20.0
# 200.0  4/4     51.0   1.0         4  0.413223       20.0    20.0
# 220.0  4/4     56.0   1.0         2  0.454545       20.0    19.0
# 239.0  4/4     60.0   4.0         5  0.493802       19.0     5.0
# 244.0  4/4     62.0   1.0         5  0.504132        5.0    36.0
# 280.0  4/4     71.0   1.0         5  0.578512       36.0    20.0
# 300.0  4/4     76.0   1.0         3  0.619835       20.0    40.0
# 340.0  4/4     86.0   1.0         4  0.702479       40.0    44.0
# 384.0  4/4     97.0   1.0         2  0.793388       44.0    20.0
# 404.0  4/4    102.0   1.0         5  0.834711       20.0    44.0
# 448.0  4/4    113.0   1.0         3  0.925620       44.0    36.0
# 484.0  4/4    122.0   1.0         5  1.000000       36.0     4.0

# %% [markdown]
# `piece.cadenceProgressPlot()` visualizza la successione delle cadenze: sull'asse x il *progress* (posizione proporzionale da 0 a 1), sull'asse y la sonorità di approdo. Con `includeType=True` i marcatori variano forma a seconda del tipo di cadenza.

# %%
piece.cadenceProgressPlot(includeType=True)

# %%
# piece.linkExamples() genera link agli esempi musicali in EMA Viewer.
# Funziona solo con file caricati da URL pubblici (celle 6-7).
cad = piece.cadences()
link_cad = piece.linkExamples(df=cad, piece_url=url)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CadType</th>
#       <th>LeadingTones</th>
#       <th>CVFs</th>
#       <th>Low</th>
#       <th>RelLow</th>
#       <th>Tone</th>
#       <th>RelTone</th>
#       <th>TSig</th>
#       <th>Measure</th>
#       <th>Beat</th>
#       <th>Sounding</th>
#       <th>Progress</th>
#       <th>SinceLast</th>
#       <th>ToNext</th>
#     </tr>
#     <tr>
#       <th>Last</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>48.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F11-13%2F1%2B4%2C1%2B4%2C1%2B4%2F%404.0-end%2B%404.0-end%2C%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=11-13&observation=+Evaded+Authentic" rel="noopener noreferrer" target="_blank">Evaded Authentic</a></td>
#       <td>1.0</td>
#       <td>Cb</td>
#       <td>G4</td>
#       <td>P15</td>
#       <td>B-</td>
#       <td>m3</td>
#       <td>4/4</td>
#       <td>13.0</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>0.099174</td>
#       <td>48.0</td>
#       <td>36.0</td>
#     </tr>
#     <tr>
#       <th>84.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F21%2C22%2F1%2B2%2B4%2C1%2B2%2B4%2F%402.0-end%401-end%2B%402.0-end%2B%401-end%2C%401-1.0%2B%401-1.0%2B%401-1.0%2Fhighlight&measure_range=21-22&observation=+Clausula+Vera" rel="noopener noreferrer" target="_blank">Clausula Vera</a></td>
#       <td>1.0</td>
#       <td>CTx</td>
#       <td>D4</td>
#       <td>P12</td>
#       <td>D</td>
#       <td>P5</td>
#       <td>4/4</td>
#       <td>22.0</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>0.173554</td>
#       <td>36.0</td>
#       <td>32.0</td>
#     </tr>
#     <tr>
#       <th>116.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F28-30%2F1%2B5%2B2%2C1%2B5%2B2%2C1%2B5%2B2%2F%403.0-end%2B%403.0-end%2B%403.0-end%2C%40all%2B%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=28-30&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>1.0</td>
#       <td>CtB</td>
#       <td>B-2</td>
#       <td>m3</td>
#       <td>B-</td>
#       <td>m3</td>
#       <td>4/4</td>
#       <td>30.0</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>0.239669</td>
#       <td>32.0</td>
#       <td>16.0</td>
#     </tr>
#     <tr>
#       <th>132.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F33%2C34%2F2%2B4%2B5%2C2%2B4%2B5%2F%402.0-end%401-end%2B%402.0-end%2B%401-end%2C%401-1.0%2B%401-1.0%2B%401-1.0%2Fhighlight&measure_range=33-34&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>1.0</td>
#       <td>CTB</td>
#       <td>G2</td>
#       <td>P1</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>34.0</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>0.272727</td>
#       <td>16.0</td>
#       <td>16.0</td>
#     </tr>
#     <tr>
#       <th>148.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F37-38%2F1%2B5%2B4%2B2%2C1%2B5%2B4%2B2%2F%402.0-end%2B%402.0-end%2B%402.0-end%2B%402.0-end%2C%40start-1.0%2B%40start-1.0%2B%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=37-38&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>1.0</td>
#       <td>TCtB</td>
#       <td>G3</td>
#       <td>P8</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>38.0</td>
#       <td>1.0</td>
#       <td>5</td>
#       <td>0.305785</td>
#       <td>16.0</td>
#       <td>32.0</td>
#     </tr>
#     <tr>
#       <th>180.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F44-46%2F1%2B3%2C1%2B3%2C1%2B3%2F%401.0-end%2B%401.0-end%2C%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=44-46&observation=+Abandoned+Authentic" rel="noopener noreferrer" target="_blank">Abandoned Authentic</a></td>
#       <td>-1.0</td>
#       <td>cx</td>
#       <td>A4</td>
#       <td>M16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4/4</td>
#       <td>46.0</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>0.371901</td>
#       <td>32.0</td>
#       <td>20.0</td>
#     </tr>
#     <tr>
#       <th>200.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F49-51%2F1%2B5%2C1%2B5%2C1%2B5%2F%401.0-end%2B%401.0-end%2C%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=49-51&observation=+Clausula+Vera" rel="noopener noreferrer" target="_blank">Clausula Vera</a></td>
#       <td>1.0</td>
#       <td>TC</td>
#       <td>G3</td>
#       <td>P8</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>51.0</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>0.413223</td>
#       <td>20.0</td>
#       <td>20.0</td>
#     </tr>
#     <tr>
#       <th>220.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F54-56%2F1%2B4%2C1%2B4%2C1%2B4%2F%403.0-end%2B%403.0-end%2C%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=54-56&observation=+Abandoned+Clausula+Vera" rel="noopener noreferrer" target="_blank">Abandoned Clausula Vera</a></td>
#       <td>1.0</td>
#       <td>zC</td>
#       <td>G4</td>
#       <td>P15</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>56.0</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>0.454545</td>
#       <td>20.0</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>239.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F60%2F2%2B4%2B5%2F%402.0-4.0%2B%402.0-4.0%401-4.0%2B%401-4.0%2Fhighlight&measure_range=60-60&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>0.0</td>
#       <td>TCB</td>
#       <td>G2</td>
#       <td>P1</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>60.0</td>
#       <td>4.0</td>
#       <td>5</td>
#       <td>0.493802</td>
#       <td>19.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>244.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F60-62%2F1%2B5%2B2%2C1%2B5%2B2%2C1%2B5%2B2%2F%404.0-end%2B%404.0-end%2B%404.0-end%2C%40all%2B%40all%2B%40all%2C%40start-1.0%2B%40start-1.0%2B%40start-1.0%2Fhighlight&measure_range=60-62&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>1.0</td>
#       <td>TCB</td>
#       <td>G2</td>
#       <td>P1</td>
#       <td>G</td>
#       <td>P8</td>
#       <td>4/4</td>
#       <td>62.0</td>
#       <td>1.0</td>
#       <td>5</td>
#       <td>0.504132</td>
#       <td>5.0</td>
#       <td>36.0</td>
#     </tr>
#     <tr>
#       <th>280.0</th>
#       <td><a href="https://RichardFreedman.github.io/ema_react_app/?pieceURL=Music_Files%2FMonteverdi_o_rossignuol.xml&ema_expression=%2F69%2C70%2C71%2F1%2B4%2B5%2C1%2B4%2B5%2C1%2B4%2B5%2F%401-end%403.0-end%2B%403.0-end%2B%401-end%2C%40all%2B%40all%2B%40all%2C%401-1.0%2B%401-1.0%2B%401-1.0%2Fhighlight&measure_range=69-71&observation=+Authentic" rel="noopener noreferrer" target="_blank">Authentic</a></td>
#       <td>1.0</td>
#       <td>CTB</td>
#       <td>D3</td>
#       <td>P5</td>
#       <td>D</td>
#       <td>P5</td>
#       <td>4/4</td>
#       <td>71.0</td>
#       <td>1.0</td>
#       <td>5</td>
#       <td>0.578512

# %% [markdown]
# #### Testo

# %% [markdown]
# `piece.lyrics()` restituisce le sillabe associate a ciascuna nota, nella stessa forma tabellare degli altri dati.

# %%
lyr = piece.lyrics()
lyr
# Out:
#       Canto Quinto Alto Tenore Basso
# 0.0     NaN    NaN  NaN      O   NaN
# 2.0     NaN    NaN  NaN    ros   NaN
# 3.0     NaN    NaN  NaN     si   NaN
# 4.0       O      O  NaN  gnuol   NaN
# 6.0     ros    ros  NaN    NaN   NaN
# ...     ...    ...  ...    ...   ...
# 480.0   cas    NaN  pri    NaN   pri
# 481.0   s'e    pri  NaN    s'e   NaN
# 482.0   pri    NaN  NaN    pri   NaN
# 483.0   NaN    NaN  NaN    NaN   NaN
# 484.0   vo.    vo.  vo.    vo.   vo.
#
# [477 rows x 5 columns]

# %% [markdown]
# ### Combinare i dati

# %% [markdown]
# I dati raccolti vengono qui uniti in un'unica tabella, che costituisce la base per i grafici nella sezione successiva. Le informazioni sulle cadenze vengono aggiunte tramite un *merge* su battuta (*measure*) e pulsazione (*beat*).

# %%
n     = piece.notes()
d     = piece.durations()
sound = piece.soundingCount()
lyr   = piece.lyrics().rename(columns=lambda v: f'Lyric_{v}')

output = piece.detailIndex(
    df=pd.concat([n, d, sound, lyr], axis=1),
    progress=True
).reset_index()

output['Composer'] = piece.metadata['composer']
output['Title']    = piece.metadata['title']
output['path']     = Path(url).name

first_cols = ['Measure', 'Beat', 'Composer', 'Title', 'path']
output = output[first_cols + [c for c in output.columns if c not in first_cols]]

cad = piece.cadences()
output = output.merge(
    cad[['Measure', 'Beat', 'CadType', 'Tone', 'CVFs']],
    on=['Measure', 'Beat'],
    how='left'
)

# normalizza progress sulla fine effettiva del brano
# (ultimo attacco + durata massima), così le ultime note non vengono tagliate
total_offsets = (d.index + d.max(axis=1)).max()
output['Progress'] *= d.index.max() / total_offsets

output
# Out:
#      Measure  Beat            Composer  \
# 0        1.0   1.0  Claudio Monteverdi
# 1        1.0   3.0  Claudio Monteverdi
# 2        1.0   4.0  Claudio Monteverdi
# 3        2.0   1.0  Claudio Monteverdi
# 4        2.0   3.0  Claudio Monteverdi
# ..       ...   ...                 ...
# 472    121.0   1.0  Claudio Monteverdi
# 473    121.0   2.0  Claudio Monteverdi
# 474    121.0   3.0  Claudio Monteverdi
# 475    121.0   4.0  Claudio Monteverdi
# 476    122.0   1.0  Claudio Monteverdi
#
#                                       Title                         path  \
# 0    O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 1    O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 2    O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 3    O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 4    O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# ..                                      ...                          ...
# 472  O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 473  O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 474  O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 475  O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
# 476  O rossignuol ch'in queste verdi fronde  Monteverdi_o_rossignuol.xml
#
#      Progress  Canto  Canto  Quinto  Quinto  ... Basso  Sounding Lyric_Canto  \
# 0    0.000000   Rest    4.0    Rest     4.0  ...  87.0         1         NaN
# 1    0.004098    NaN    NaN     NaN     NaN  ...   NaN         1         NaN
# 2    0.006148    NaN    NaN     NaN     NaN  ...   NaN         1         NaN
# 3    0.008197     D5    2.0     B-4     2.0  ...   NaN         3           O
# 4    0.012295     D5    1.0     B-4     1.0  ...   NaN         2         ros
# ..        ...    ...    ...     ...     ...  ...   ...       ...         ...
# 472  0.983607    F#4    1.0     NaN     NaN  ...   4.0         5         cas
# 473  0.985656     G4    1.0      G4     2.0  ...   NaN         5         s'e
# 474  0.987705     A4    2.0     NaN     NaN  ...   NaN         5         pri
# 475  0.989754    NaN    NaN     F#4     1.0  ...   NaN         5         NaN
# 476  0.991803     B4    4.0      G4     4.0  ...   4.0         5         vo.
#
#      Lyric_Quinto Lyric_Alto  Lyric_Tenore Lyric_Basso    CadType Tone  CVFs
# 0             NaN        NaN             O         NaN        NaN  NaN   NaN
# 1             NaN        NaN           ros         NaN        NaN  NaN   NaN
# 2             NaN        NaN            si         NaN        NaN  NaN   NaN
# 3               O        NaN         gnuol         NaN        NaN  NaN   NaN
# 4             ros        NaN           NaN         NaN        NaN  NaN   NaN
# ..            ...        ...           ...         ...        ...  ...   ...
# 472           NaN        pri           NaN         pri        NaN  NaN   NaN
# 473           pri        NaN           s'e         NaN        NaN  NaN   NaN
# 474           NaN        NaN           pri         NaN        NaN  NaN   NaN
# 475           NaN        NaN           NaN         NaN        NaN  NaN   NaN
# 476           vo.        vo.           vo.         vo.  Authentic    G  tCTB
#
# [477 rows x 35 columns]

# %% [markdown]
# ## Grafici

# %% [markdown]
# ### Attività delle voci
#
# Ogni riga corrisponde a una voce; ogni 'mattone' rappresenta una nota, posizionata in base alla sua posizione nella composizione e della dimensione corrispondente alla sua durata. Le linee rosse tratteggiate segnalano le cadenze rilevate da `piece.cadences()`; il righello in basso indica i numeri di battuta.

# %%
# voice columns: each voice appears twice in output (notes, then durations)
all_cols = list(output.columns)
voices   = n.columns.tolist()
note_idx = {v: all_cols.index(v)                for v in voices}
dur_idx  = {v: all_cols.index(v, note_idx[v]+1) for v in voices}

# measure ruler — reused in all three chart cells
measures       = output.groupby('Measure')['Progress'].min()
measure_lines  = [
    dict(type='line', x0=p, x1=p, y0=0, y1=1,
         xref='x', yref='paper', line=dict(color='#ddd', width=0.5))
    for p in measures.values
]
measure_labels = [
    dict(x=p, y=0, xref='x', yref='paper', text=str(int(m)),
         showarrow=False, yanchor='top', xanchor='center', font=dict(size=8))
    for m, p in measures.items() if m == 1 or m % 5 == 0
]

file_stem = url.split('/')[-1].rsplit('.', 1)[0]

# cadence markers — reused in all three chart cells
CAD_ABBR = {'Clausula Vera': 'CV', 'Authentic': 'Auth.', 'Evaded': 'Evad.', 'Abandoned': 'Aband.'}

def shorten_cad(name):
    for word, abbr in CAD_ABBR.items():
        name = name.replace(word, abbr)
    return name.strip()

cad_rows  = output.dropna(subset=['CadType'])
cad_lines = [
    dict(type='line', x0=row['Progress'], x1=row['Progress'], y0=0, y1=1,
         xref='x', yref='paper', line=dict(color='#c00', width=1, dash='dot'))
    for _, row in cad_rows.iterrows()
]
cad_labels = [
    dict(x=row['Progress'], y=1, xref='x', yref='paper',
         text=shorten_cad(row['CadType']) + (f"<br><b>{row['Tone']}</b>" if pd.notna(row['Tone']) else ''),
         showarrow=False, yanchor='bottom', xanchor='center',
         font=dict(size=7, color='#c00'))
    for _, row in cad_rows.iterrows()
]

palette = ['#4472C4','#ED7D31','#70AD47','#FFC000','#7030A0',
           '#FF6B6B','#00B0F0','#92D050','#FF00FF','#00B050']

def add_voice_traces(fig, row=None, col=None):
    for voice, color in zip(voices, cycle(palette)):
        notes   = output.iloc[:, note_idx[voice]]
        durs    = output.iloc[:, dur_idx[voice]]
        active  = notes.notna() & (notes != 'Rest')
        lyr_col = f'Lyric_{voice}'
        lyrics  = (output[lyr_col][active].fillna('').astype(str)
                   if lyr_col in output.columns
                   else pd.Series('', index=notes[active].index))
        fig.add_trace(go.Bar(
            name        = voice,
            orientation = 'h',
            x           = (durs[active].astype(float) / total_offsets).tolist(),
            y           = [voice] * int(active.sum()),
            base        = output.loc[active, 'Progress'].tolist(),
            marker      = dict(color=color, line=dict(width=0)),
            customdata  = pd.DataFrame({
                'measure': output.loc[active, 'Measure'].astype(int),
                'beat':    output.loc[active, 'Beat'],
                'pitch':   notes[active].astype(str),
                'dur':     durs[active].astype(float),
                'lyric':   lyrics,
            }).values,
            hovertemplate = (
                f'<b>{voice}</b><br>'
                'M %{customdata[0]}  b %{customdata[1]}<br>'
                'Pitch: %{customdata[2]}  Dur: %{customdata[3]:.0f}<br>'
                'Lyric: %{customdata[4]}<br>'
                '<extra></extra>'
            ),
        ), row=row, col=col)

fig = go.Figure()
add_voice_traces(fig)
fig.update_layout(
    title        = f"Voice activity: {output['Title'].iloc[0]}  —  {output['Composer'].iloc[0]}",
    barmode      = 'overlay',
    height       = 150 + len(voices) * 45,
    showlegend   = False,
    plot_bgcolor = 'white',
    margin       = dict(l=80, r=20, t=70, b=40),
    xaxis        = dict(range=[0, 1], showgrid=False, showticklabels=False),
    yaxis        = dict(title=None, categoryorder='array', categoryarray=list(reversed(voices))),
    shapes       = measure_lines + cad_lines,
    annotations  = measure_labels + cad_labels,
)
fig.show()
download_html(fig, f'voice_activity_{file_stem}.html')
# Out:
# <a href="data:text/html;base64,..." download="voice_activity_Monteverdi_o_rossignuol.html" style="display:inline-block;margin-top:6px;padding:4px 14px;background:#4472C4;color:#fff;border-radius:4px;text-decoration:none;font-size:12px;">&#8595; voice_activity_Monteverdi_o_rossignuol.html</a>

# %% [markdown]
# ### Sonorità complessiva
#
# Ogni colonna indica quante voci sono attive in quel momento. L'asse x è lo stesso del grafico precedente; le cadenze sono riportate con le stesse linee rosse.

# %%
sounding = (output[['Progress', 'Measure', 'Beat', 'Sounding']]
            .dropna(subset=['Sounding'])
            .astype({'Measure': int})
            .reset_index(drop=True))

pos    = sounding['Progress'].values
widths = np.append(np.diff(pos), 1.0 - pos[-1])

fig_s = go.Figure(go.Bar(
    x             = (pos + widths / 2).tolist(),
    y             = sounding['Sounding'].tolist(),
    width         = widths.tolist(),
    marker        = dict(color='#4472C4', line=dict(width=0)),
    customdata    = sounding[['Measure', 'Beat', 'Sounding']].values,
    hovertemplate = (
        'M %{customdata[0]}  b %{customdata[1]}<br>'
        'Sounding: %{customdata[2]:.0f}<br>'
        '<extra></extra>'
    ),
))
fig_s.update_layout(
    title        = f"Sounding voices: {output['Title'].iloc[0]}  —  {output['Composer'].iloc[0]}",
    height       = 250,
    showlegend   = False,
    plot_bgcolor = 'white',
    bargap       = 0,
    margin       = dict(l=60, r=20, t=70, b=40),
    xaxis        = dict(range=[0, 1], showgrid=False, showticklabels=False),
    yaxis        = dict(title='Sounding count', dtick=1),
    shapes       = measure_lines + cad_lines,
    annotations  = measure_labels + cad_labels,
)
fig_s.show()
download_html(fig_s, f'sounding_voices_{file_stem}.html')
# Out:
# <a href="data:text/html;base64,..." download="sounding_voices_Monteverdi_o_rossignuol.html" style="display:inline-block;margin-top:6px;padding:4px 14px;background:#4472C4;color:#fff;border-radius:4px;text-decoration:none;font-size:12px;">&#8595; sounding_voices_Monteverdi_o_rossignuol.html</a>

# %% [markdown]
# ### Vista combinata
#
# Questo grafico offre una visione combinata dei due grafici precedenti.

# %%
from plotly.subplots import make_subplots

fig_c = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    row_heights=[0.72, 0.28],
    vertical_spacing=0.04,
)
add_voice_traces(fig_c, row=1, col=1)

fig_c.add_trace(go.Bar(
    x             = (pos + widths / 2).tolist(),
    y             = sounding['Sounding'].tolist(),
    width         = widths.tolist(),
    marker        = dict(color='#4472C4', line=dict(width=0)),
    customdata    = sounding[['Measure', 'Beat', 'Sounding']].values,
    showlegend    = False,
    hovertemplate = (
        'M %{customdata[0]}  b %{customdata[1]}<br>'
        'Sounding: %{customdata[2]:.0f}<br>'
        '<extra></extra>'
    ),
), row=2, col=1)

sep_y    = (fig_c.layout.yaxis2.domain[1] + fig_c.layout.yaxis.domain[0]) / 2
sep_line = dict(type='line', x0=0, x1=1, y0=sep_y, y1=sep_y,
                xref='paper', yref='paper', line=dict(color='#aaa', width=1))

fig_c.update_layout(
    title        = f"{output['Title'].iloc[0]}  —  {output['Composer'].iloc[0]}",
    barmode      = 'overlay',
    height       = 150 + len(voices) * 45 + 180,
    showlegend   = False,
    plot_bgcolor = 'white',
    margin       = dict(l=80, r=20, t=70, b=40),
    shapes       = cad_lines + [sep_line],
    annotations  = measure_labels + cad_labels,
)
fig_c.update_xaxes(range=[0, 1], showgrid=False, showticklabels=False)
fig_c.update_yaxes(title_text=None, categoryorder='array',
                   categoryarray=list(reversed(voices)), row=1, col=1)
fig_c.update_yaxes(title_text='Sounding count', dtick=1, row=2, col=1)
fig_c.show()
download_html(fig_c, f'combined_{file_stem}.html')
# Out:
# <a href="data:text/html;base64,..." download="combined_Monteverdi_o_rossignuol.html" style="display:inline-block;margin-top:6px;padding:4px 14px;background:#4472C4;color:#fff;border-radius:4px;text-decoration:none;font-size:12px;">&#8595; combined_Monteverdi_o_rossignuol.html</a>
